# %%
import pandas as pd
import json
arr = pd.read_json('locations.json')
for i in range(len(arr)):
    s = ' '.join(arr[0][i].split(' ')[::-1])
    s = ','.join(s.split(' '))
    arr[0][i] = s
arr = arr[0]
arr.to_json('address.json')
