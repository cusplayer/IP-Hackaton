# %%
import json
import pandas as pd
arr = pd.read_json('address.json', 'index')
print(arr)
t = []
for i in range(len(arr)):
    t.append('new google.maps.LatLng(' + arr[0][i] + ')')
with open('t.json', 'w') as f:
    f.write(json.dumps(t))
# Out:
#                        0
# 0    55.751325,37.612263
# 1    55.763498,37.593345
# 10   55.752116,37.718435
# 100  55.766587,37.699598
# 101  55.718121,37.661814
# ..                   ...
# 95    55.66929,37.625936
# 96   55.730025,37.773718
# 97   55.706026,37.689788
# 98   55.795535,37.798511
# 99   55.761467,37.772172
#
# [272 rows x 1 columns]
# 0
# 55.751325,37.612263
# 1
# 55.763498,37.593345
# 2
# 55.740553,37.656038
# 3
# 55.758534,37.598834
# 4
# 55.767159,37.595752
# 5
# 55.686975,37.544997
# 6
# 55.770168,37.583391
# 7
# 55.657966,37.543075
# 8
# 55.744743,37.513215
# 9
# 55.726309,37.560484
# 10
# 55.752116,37.718435
# 11
# 55.723536,37.401447
# 12
# 55.64289,37.521758
# 13
# 55.757845,37.69428
# 14
# 55.747105,37.774598
# 15
# 55.778785,37.827581
# 16
# 55.784967,37.352399
# 17
# 55.595771,37.606325
# 18
# 55.76719,37.81292
# 19
# 55.745215,37.776278
# 20
# 55.650576,37.531882
# 21
# 55.793627,37.811582
# 22
# 55.644633,37.665596
# 23
# 55.737177,37.765399
# 24
# ...
